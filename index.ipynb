# %%
#!Python3
print("Content-Type: text/html")
print()
import cgi, os
# Out:
# Content-Type: text/html

# %%
files = os.listdir('data')
listStr = ''
for item in files:
  listStr = listStr + 
  '<li><a href="index.py?id={name}">{name}</a></li>.format(name=item)'
  
form = cgi.FieldStorage()
if 'id' in form:
  pageId = form["id"].value
  description = open('data'/+pageId, 'r').read()
else:
  pageId = 'Welcome'
  description = 'Hello, web'
  
print('''<!doctype html>
<html>
<head>
  <title>WEB1 - Welcome</title>
  <meta charset='utf-8'>  
  </head>
  <body>
    <h1><a rhef='index.py'>WEB</a></h1>
    <ol>
    {listStr}
    </ol>
    <h2>{title}</h2>
    <p>{desc}</p>
  </body>
</html>
'''.format(title=pageId, desc=description, listStr=listStr))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-83a992666ab1> in <module>()
# ----> 1 files = os.listdir('data')
#       2 listStr = ''
#       3 for item in files:
#       4   listStr = listStr + '<li><a href="index.py?id={name}">{name}</a></li>.format(name=item)'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'
